# %%
import tweepy
from textblob import TextBlob
api_key='WtmfuVhOHndoC7R25vPUInY6V'
api_secret_key='TQpxYT3zpG7UCSNX4SXC2ssSX98wNBGX5nqlPn7B3Fg81CcUXh'
access_token='941958317315842048-QqFuDjv2rx4xE0Btg9yj7W4CwLLu0La'
access_token_secret= 'g6G36surF46Znn9IVSyel9KO1pZoTtXNjumYoWB67xGPi'
auth=tweepy.OAuthHandler(api_key,api_secret_key)
auth.set_access_token(access_token,access_token_secret)
api=tweepy.API(auth)
public_tweets=api.search(input("which tweet you wanna search? "))
for tweet in public_tweets:                              
                               print(tweet.text)
                               textblob_object=TextBlob(tweet.text)
                               sentiment_polarity=textblob_object.sentiment.polarity
                               print("positive") if sentiment_polarity>0 and sentiment_polarity<=1 else print("Negative") if sentiment_polarity<0 else print("Neutral")
# Out:
# which tweet you wanna search? abdul kalam
# @chittukuruvi4 @DeshBhaktReva @Tejasvi_Surya @UdayMahurkar @RudraVS Yes in Karnataka congress party told that he is… https://t.co/IbpM6NkzKz
# Neutral
# @SardarMajidIsh1 @GeneralBakshi Madarsa education is biggest problems where 1 Muslim becomes Abdul kalam and 99 become jihadi
# Neutral
# RT @HrsCenter: 🔴 LIVE KAJIAN MALAM [KALAM]
#
# 🗓️ Senin, 12 Okt. 2020
# ⏰ Pukul : 19.30 - 21.00 WIB
# 🎯 Tema : "Aksi Penolakan UU Ciptaker"
#
# 📞 Sp…
# positive
# RT @WPCPSFION: INTEGRATED TEST RANGE FACILITY
# ABDUL KALAM ISLAND, ODISHA, 10 KILOMETRES OFF EASTERN COAST OF INDIA
#
# 1030 Hours
#
# Indian Nir…
# Neutral
# RT @HrsCenter: 🔴 LIVE KAJIAN MALAM [KALAM]
#
# 🗓️ Senin, 12 Okt. 2020
# ⏰ Pukul : 19.30 - 21.00 WIB
# 🎯 Tema : "Aksi Penolakan UU Ciptaker"
#
# 📞 Sp…
# positive
# RT @janmajit007: 3/15
# 2nd test of HSTDV was conducted, the 1st test was conducted in 2019 &amp; it was not entirely successful but this time it…
# Negative
# 3/15
# ...
